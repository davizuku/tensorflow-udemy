# %%
import tensorflow as tf

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def showRegressionLine(x, y, pred_m, pred_n):
    y_pred = pred_m * x + pred_n
    plt.scatter(x, y)
    plt.plot(x, y_pred, c='red')
    plt.show()

# %%
def testRegressionLine(num_samples, random_seed = 1234, iterations = 100):
    print('testRegressionLine', num_samples, random_seed, iterations)
    np.random.seed(random_seed)
    x_data = np.linspace(0, 10, num_samples)
    y_labels = 2 * x_data + np.random.normal(loc=0, scale=2, size=num_samples)
    plt.scatter(x_data, y_labels)
    plt.show()
    # y = m * x + n
    x = tf.placeholder(dtype=tf.float64)
    n = tf.Variable(0.9287885, dtype=tf.float64)
    m = tf.Variable(-2.3367832, dtype=tf.float64)
    error = 0
    for (x, y) in zip(x_data, y_labels):
        y_hat = m * x + n
        error += (y_hat - y)**2

    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
    train = optimizer.minimize(error)
    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        for i in range(iterations):
            sess.run(train)
        pred_m, pred_n = sess.run([m, n])
    showRegressionLine(x_data, y_labels, pred_m, pred_n)
    print('y = ' + str(pred_m) + ' * x + ' + str(pred_n))
    print('\n')

# %%
for i in range(10, 10, 10):
    testRegressionLine(num_samples=i, iterations = 10)
# Out:
# testRegressionLine 10 1234 10
# y = 1.6827799488 * x + 1.46879925147
#
#
# testRegressionLine 20 1234 10
# y = 1.78162725646 * x + 1.3938138271
#
#
# testRegressionLine 30 1234 10
# y = -6.99140216648 * x + 0.0106798253445
#
#
# testRegressionLine 40 1234 10
# y = -1195.54387557 * x + -177.49630396
#
#
# testRegressionLine 50 1234 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-fab0ff0293aa> in <module>()
#       1 for i in range(10, 100, 10):
# ----> 2     testRegressionLine(num_samples=i, iterations = 10)
#
# <ipython-input-33-d2f1673d588d> in testRegressionLine(num_samples, random_seed, iterations)
#      19     init = tf.global_variables_initializer()
#      20     with tf.Session() as sess:
# ---> 21         sess.run(init)
#      22         for i in range(iterations):
#      23             sess.run(train)
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1295                 run_metadata):
#    1296       # Ensure any changes to the graph are reflected in the runtime.
# -> 1297       self._extend_graph()
#    1298       with errors.raise_exception_on_not_ok_status() as status:
#    1299         if self._created_with_new_api:
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1356         with errors.raise_exception_on_not_ok_status() as status:
#    1357           tf_session.TF_ExtendGraph(
# -> 1358               self._session, graph_def.SerializeToString(), status)
#    1359         self._opened = True
#    1360
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in SerializeToString(self, **kwargs)
#    1035           'Message %s is missing required fields: %s' % (
#    1036           self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1037     return self.SerializePartialToString(**kwargs)
#    1038   cls.SerializeToString = SerializeToString
#    1039
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in SerializePartialToString(self, **kwargs)
#    1044   def SerializePartialToString(self, **kwargs):
#    1045     out = BytesIO()
# -> 1046     self._InternalSerialize(out.write, **kwargs)
#    1047     return out.getvalue()
#    1048   cls.SerializePartialToString = SerializePartialToString
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in InternalSerialize(self, write_bytes, deterministic)
#    1055       deterministic = bool(deterministic)
#    1056     for field_descriptor, field_value in self.ListFields():
# -> 1057       field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1058     for tag_bytes, value_bytes in self._unknown_fields:
#    1059       write_bytes(tag_bytes)
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in EncodeRepeatedField(write, value, deterministic)
#     757       for element in value:
#     758         write(tag)
# --> 759         local_EncodeVarint(write, element.ByteSize(), deterministic)
#     760         element._InternalSerialize(write, deterministic)
#     761     return EncodeRepeatedField
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1012     size = 0
#    1013     for field_descriptor, field_value in self.ListFields():
# -> 1014       size += field_descriptor._sizer(field_value)
#    1015
#    1016     for tag_bytes, value_bytes in self._unknown_fields:
#
# //anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in RepeatedFieldSize(value)
#     238     def RepeatedFieldSize(value):
#     239       result = tag_size * len(value)
# --> 240       for element in value:
#     241         l = local_len(element.encode('utf-8'))
#     242         result += local_VarintSize(l) + l
#
# KeyboardInterrupt:
